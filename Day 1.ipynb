# %%
import os
import re

# %%
def find_and_replace(line):
    line = line.replace("one", "o1e")
    line = line.replace("two", "t2o")
    line = line.replace("three", "t3e")
    line = line.replace("four", "4")
    line = line.replace("five", "5e")
    line = line.replace("six", "6")
    line = line.replace("seven", "7n")
    line = line.replace("eight", "e8t")
    line = line.replace("nine", "n9e")
    return line

# %%
data_file = open("data_files/aoc_1.txt")
data = []
rolling_sum = 0
for l in data_file:
    
    temp = l.replace("\n","")
#     temp = find_and_replace(temp)
    data.append(temp)
      
for r in data:
    temp = ''
    digits = re.sub("[^0-9]", "", r)
    print(r)
    if digits == "":
        continue
    if len(digits) < 2:
        temp = digits + digits
    else:
        temp = digits[0] + digits[-1]
    print(temp)
    rolling_sum += int(temp)
display(rolling_sum)
# Out:
# 9dlvndqbddghpxc
# 9dlvndqbddghpxc
# rtkrbtthree8sixfoureight6
# rtkrbtthree8sixfoureight6
# fdxrqmfxdkstpmcj7lmphgsmqqnmjrtwo3tcbc
# fdxrqmfxdkstpmcj7lmphgsmqqnmjrtwo3tcbc
# onetjcsmgk57nvmkvcvkdtqtsksgpchsfsjzkkmb
# onetjcsmgk57nvmkvcvkdtqtsksgpchsfsjzkkmb
# six8threepvlxttc85two
# six8threepvlxttc85two
# 8five9ttqst2one2vz
# 8five9ttqst2one2vz
# hbrmhsnjeight64dgdnvdbspk7ninetzbvjczqrj
# hbrmhsnjeight64dgdnvdbspk7ninetzbvjczqrj
# fourtwofivesix5
# fourtwofivesix5
# 3gksfourqf48
# 3gksfourqf48
# 7one1tnqxfvhmjvjzfive
# 7one1tnqxfvhmjvjzfive
# sevenmcjs3lmlmxmcgptwobjggfive6four
# sevenmcjs3lmlmxmcgptwobjggfive6four
# seven8five3
# seven8five3
# 5sfknxsn5sevenfour446
# 5sfknxsn5sevenfour446
# bxc5two67seven2
# bxc5two67seven2
# jcsfivefive89seven85
# jcsfivefive89seven85
# nine296
# nine296
# seven5twoeight
# seven5twoeight
# 1eighttwo8jfnhmfivefivezdsxqxqsjkone
# 1eighttwo8jfnhmfivefivezdsxqxqsjkone
# foureight48sbkkvc17zbksgvcbb
# foureight48sbkkvc17zbksgvcbb
# lnzgspccsn4cxqqdbkj
# ...
